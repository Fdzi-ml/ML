# %% [markdown]
# **this project aims to use RNN and LSTM in finding short term pattern and use linear and tree models to train a general long pattern to rise up the accuracy and lower the RMSLE,data is stock price of apple industry and we want to predict last 10 days from data base**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import sklearn as sk
# !pip install lightgbm
import lightgbm
import os
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
os.chdir("/content/drive/MyDrive")
data=pd.read_csv("apple_stock_data.csv",parse_dates=['Date'])

# %% [markdown]
# the data is consist of Date and stock price of apple industry and volume

# %%
data
# Out:
#                          Date   Adj Close       Close        High         Low  \
# 0   2023-11-02 00:00:00+00:00  176.665985  177.570007  177.779999  175.460007
# 1   2023-11-03 00:00:00+00:00  175.750671  176.649994  176.820007  173.350006
# 2   2023-11-06 00:00:00+00:00  178.317520  179.229996  179.429993  176.210007
# 3   2023-11-07 00:00:00+00:00  180.894333  181.820007  182.440002  178.970001
# 4   2023-11-08 00:00:00+00:00  181.958893  182.889999  183.449997  181.589996
# ..                        ...         ...         ...         ...         ...
# 247 2024-10-28 00:00:00+00:00  233.399994  233.399994  234.729996  232.550003
# 248 2024-10-29 00:00:00+00:00  233.669998  233.669998  234.330002  232.320007
# 249 2024-10-30 00:00:00+00:00  230.100006  230.100006  233.470001  229.550003
# 250 2024-10-31 00:00:00+00:00  225.910004  225.910004  229.830002  225.369995
# 251 2024-11-01 00:00:00+00:00  222.910004  222.910004  225.350006  220.270004
#
#            Open    Volume
# 0    175.520004  77334800
# 1    174.240005  79763700
# 2    176.380005  63841300
# 3    179.179993  70530000
# 4    182.350006  49340300
# ..          ...       ...
# 247  233.320007  36087100
# 248  233.100006  35417200
# 249  232.610001  47070900
# 250  229.339996  64370100
# 251  220.970001  65242200
#
# [252 rows x 7 columns]

# %%
data=data.sort_values(ascending=False,by=['Date'])

# %%
data.sort_values(by=["Date"],inplace=True,ascending=True)
data.Date.head(20)
# Out:
# 0    2023-11-02 00:00:00+00:00
# 1    2023-11-03 00:00:00+00:00
# 2    2023-11-06 00:00:00+00:00
# 3    2023-11-07 00:00:00+00:00
# 4    2023-11-08 00:00:00+00:00
# 5    2023-11-09 00:00:00+00:00
# 6    2023-11-10 00:00:00+00:00
# 7    2023-11-13 00:00:00+00:00
# 8    2023-11-14 00:00:00+00:00
# 9    2023-11-15 00:00:00+00:00
# 10   2023-11-16 00:00:00+00:00
# 11   2023-11-17 00:00:00+00:00
# 12   2023-11-20 00:00:00+00:00
# 13   2023-11-21 00:00:00+00:00
# 14   2023-11-22 00:00:00+00:00
# 15   2023-11-24 00:00:00+00:00
# 16   2023-11-27 00:00:00+00:00
# 17   2023-11-28 00:00:00+00:00
# 18   2023-11-29 00:00:00+00:00
# 19   2023-11-30 00:00:00+00:00
# Name: Date, dtype: datetime64[ns, UTC]

# %%
da=data.copy()

# %% [markdown]
# **The first step in building our first RNN model is to give date time in a suitable way and with giving Date time in seperate coulmns gives a proper result**

# %%
da["saleYear"] = da.Date.dt.year
da["saleMonth"] = da.Date.dt.month
da["saleDay"] = da.Date.dt.day
da["saleDayofweek"] = da.Date.dt.dayofweek
da["saleDayofyear"] = da.Date.dt.dayofyear
da.drop("Date", axis=1, inplace=True)

# %%
da
# Out:
#       Adj Close       Close        High         Low        Open    Volume  \
# 0    176.665985  177.570007  177.779999  175.460007  175.520004  77334800
# 1    175.750671  176.649994  176.820007  173.350006  174.240005  79763700
# 2    178.317520  179.229996  179.429993  176.210007  176.380005  63841300
# 3    180.894333  181.820007  182.440002  178.970001  179.179993  70530000
# 4    181.958893  182.889999  183.449997  181.589996  182.350006  49340300
# ..          ...         ...         ...         ...         ...       ...
# 247  233.399994  233.399994  234.729996  232.550003  233.320007  36087100
# 248  233.669998  233.669998  234.330002  232.320007  233.100006  35417200
# 249  230.100006  230.100006  233.470001  229.550003  232.610001  47070900
# 250  225.910004  225.910004  229.830002  225.369995  229.339996  64370100
# 251  222.910004  222.910004  225.350006  220.270004  220.970001  65242200
#
#      saleYear  saleMonth  saleDay  saleDayofweek  saleDayofyear
# 0        2023         11        2              3            306
# 1        2023         11        3              4            307
# 2        2023         11        6              0            310
# 3        2023         11        7              1            311
# 4        2023         11        8              2            312
# ..        ...        ...      ...            ...            ...
# 247      2024         10       28              0            302
# 248      2024         10       29              1            303
# 249      2024         10       30              2            304
# 250      2024         10       31              3            305
# 251      2024         11        1              4            306
#
# [252 rows x 11 columns]

# %%
da.isnull().sum()
# Out:
# Adj Close        0
# Close            0
# High             0
# Low              0
# Open             0
# Volume           0
# saleYear         0
# saleMonth        0
# saleDay          0
# saleDayofweek    0
# saleDayofyear    0
# dtype: int64

# %%
da.drop(columns=['Low','High','Adj Close','Open','Volume'],inplace=True)

# %%
da.columns
# Out:
# Index(['Close', 'saleYear', 'saleMonth', 'saleDay', 'saleDayofweek',
#        'saleDayofyear'],
#       dtype='object')

# %%
da.Close=da.Close/da.Close.max()

# %%
da
# Out:
#                               Close
# Date
# 2023-11-02 00:00:00+00:00  0.750888
# 2023-11-03 00:00:00+00:00  0.746998
# 2023-11-06 00:00:00+00:00  0.757908
# 2023-11-07 00:00:00+00:00  0.768860
# 2023-11-08 00:00:00+00:00  0.773385
# ...                             ...
# 2024-10-28 00:00:00+00:00  0.986976
# 2024-10-29 00:00:00+00:00  0.988117
# 2024-10-30 00:00:00+00:00  0.973021
# 2024-10-31 00:00:00+00:00  0.955303
# 2024-11-01 00:00:00+00:00  0.942617
#
# [252 rows x 1 columns]

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

# %%
from tensorflow.keras.layers import SimpleRNN

# %%
da
# Out:
#                               Close
# Date
# 2023-11-02 00:00:00+00:00  0.750888
# 2023-11-03 00:00:00+00:00  0.746998
# 2023-11-06 00:00:00+00:00  0.757908
# 2023-11-07 00:00:00+00:00  0.768860
# 2023-11-08 00:00:00+00:00  0.773385
# ...                             ...
# 2024-10-28 00:00:00+00:00  0.986976
# 2024-10-29 00:00:00+00:00  0.988117
# 2024-10-30 00:00:00+00:00  0.973021
# 2024-10-31 00:00:00+00:00  0.955303
# 2024-11-01 00:00:00+00:00  0.942617
#
# [252 rows x 1 columns]

# %% [markdown]
# now model will be trained to predict last 10 days in our data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test=da.drop(columns=["Close"])[0:len(da)-10],da.drop(columns=["Close"])[len(da)-10:]
y_train, y_test=da.Close[0:len(da)-10],da.Close[len(da)-10:]

# %%
X_train
# Out:
#      saleYear  saleMonth  saleDay  saleDayofweek  saleDayofyear
# 0        2023         11        2              3            306
# 1        2023         11        3              4            307
# 2        2023         11        6              0            310
# 3        2023         11        7              1            311
# 4        2023         11        8              2            312
# ..        ...        ...      ...            ...            ...
# 237      2024         10       14              0            288
# 238      2024         10       15              1            289
# 239      2024         10       16              2            290
# 240      2024         10       17              3            291
# 241      2024         10       18              4            292
#
# [242 rows x 5 columns]

# %%
model = Sequential()
model.add(SimpleRNN(units=300, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(SimpleRNN(units=150,  return_sequences=True))
model.add(SimpleRNN(units=150,  return_sequences=True))
model.add(SimpleRNN(units=40,  return_sequences=True))
model.add(SimpleRNN(units=10))
model.add(Dense(1))
model.compile(loss='MSE', optimizer='adam',metrics=['mean_squared_error'])
model.fit(X_train, y_train,epochs=250, batch_size=32)
# Out:
# Epoch 1/250
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 1.3194 - mean_squared_error: 1.3194
# Epoch 2/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 3/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 4/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 5/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 6/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 7/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 8/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 9/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 10/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 11/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 12/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 13/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 14/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 15/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 16/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 17/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 18/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 19/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 20/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 21/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 22/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 23/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 24/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 25/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 26/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 27/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 28/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 29/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 30/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 31/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 32/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 33/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 34/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 35/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 36/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 37/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 38/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 39/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 40/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 41/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 42/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 43/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 44/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.7945e-04 - mean_squared_error: 9.7945e-04
# Epoch 45/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 46/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 47/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 48/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 49/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 50/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 51/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 52/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 53/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 54/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 55/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.9314e-04 - mean_squared_error: 9.9314e-04
# Epoch 56/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8055e-04 - mean_squared_error: 8.8055e-04
# Epoch 57/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.8940e-04 - mean_squared_error: 9.8940e-04
# Epoch 58/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.6305e-04 - mean_squared_error: 9.6305e-04
# Epoch 59/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 60/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 61/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 62/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 63/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 64/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 65/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 66/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 67/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 68/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 69/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 70/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 71/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 72/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 73/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 74/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 75/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 76/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 77/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.2576e-04 - mean_squared_error: 9.2576e-04
# Epoch 78/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 79/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 80/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 81/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 82/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 83/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 84/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 85/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 86/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 87/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 88/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 89/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 90/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 91/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 92/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 93/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 94/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 95/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 96/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 97/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.8744e-04 - mean_squared_error: 9.8744e-04
# Epoch 98/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 9.4894e-04 - mean_squared_error: 9.4894e-04
# Epoch 99/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.3726e-04 - mean_squared_error: 9.3726e-04
# Epoch 100/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.3522e-04 - mean_squared_error: 8.3522e-04
# Epoch 101/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.5980e-04 - mean_squared_error: 7.5980e-04
# Epoch 102/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.8447e-04 - mean_squared_error: 8.8447e-04
# Epoch 103/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8156e-04 - mean_squared_error: 8.8156e-04
# Epoch 104/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.0295e-04 - mean_squared_error: 9.0295e-04
# Epoch 105/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.4072e-04 - mean_squared_error: 9.4072e-04
# Epoch 106/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9
250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.5599e-04 - mean_squared_error: 2.5599e-04
# Epoch 248/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1574e-04 - mean_squared_error: 4.1574e-04
# Epoch 249/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.2844e-04 - mean_squared_error: 3.2844e-04
# Epoch 250/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7009e-04 - mean_squared_error: 2.7009e-04

# %%
y_hat = model.predict(X_train)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.plot(range(len(y_train)), y_train)
plt.plot(range(len(y_hat)), y_hat)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step

# %%
m=np.reshape(model.predict(X_test),(10,))
rmsle(y_test,m)
m*data.Close.max()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# array([229.28505, 229.41907, 229.67125, 230.03693, 230.47116, 226.69092,
#        226.22723, 226.0019 , 226.01422, 179.14554], dtype=float32)

# %% [markdown]
# next step is to sparate train,test data into sequncese and give them to out LSTM , linear and tree models

# %%
import numpy as np
def create_sequences(da, seq_length=60):
    X, y = [], []
    for i in range(len(da) - seq_length):
        X.append(da[i:i+seq_length])
        y.append(da[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(da['Close'].values, seq_length)
train_size = int(len(X) * 0.95)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm_model = Sequential()
lstm_model.add(LSTM(units=70, return_sequences=True, input_shape=(X_train.shape[1], 1)))
lstm_model.add(LSTM(units=15))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer='adam', loss='mean_squared_error')
lstm_model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 0.0619
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0085
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0093
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0051
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0015
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0024
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0017
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0012
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0013
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0012
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0013
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0011
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0011
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0011
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0011
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0011
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 9.4712e-04
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0011
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0011
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 8.8438e-04
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 9.9323e-04
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 8.6221e-04
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0010
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0010
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 8.8942e-04
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 9.0569e-04
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 9.5371e-04
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 9.6612e-04
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 8.1023e-04
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 9.6696e-04
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 8.5507e-04
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 9.9270e-04
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 8.2818e-04
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 8.3496e-04
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 9.1217e-04
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 8.9539e-04
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 9.1269e-04
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 8.5541e-04
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.9181e-04
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 8.7787e-04
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 9.0959e-04
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.6238e-04
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 8.2367e-04
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 9.4355e-04
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8.1405e-04
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 8.9725e-04
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 9.7794e-04
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 8.1468e-04
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 8.3865e-04
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 9.0949e-04
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 8.6707e-04
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8.0597e-04
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 9.7685e-04
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 8.1470e-04
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 9.5630e-04
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 8.6966e-04
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 8.3747e-04
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 7.8853e-04
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 6.8883e-04
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 7.3149e-04
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 8.4266e-04
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 7.9937e-04
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 7.4039e-04
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 7.7988e-04
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 8.2644e-04
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.8386e-04
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.4120e-04
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 7.7275e-04
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 7.6017e-04
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 7.3341e-04
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6.5177e-04
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.5671e-04
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 7.0913e-04
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 7.8687e-04
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 7.7149e-04
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.8925e-04
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.5512e-04
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.7375e-04
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.1755e-04
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 9.6351e-04
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 6.6962e-04
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 8.0343e-04
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.0243e-04
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 6.9998e-04
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 6.8452e-04
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 9.2697e-04
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0011
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 7.6271e-04
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 7.9127e-04
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 7.1292e-04
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 8.1872e-04
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 6.6046e-04
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 6.8134e-04
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 5.8773e-04
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 6.0017e-04
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 6.8314e-04
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.0384e-04
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.2722e-04
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 5.9833e-04
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.7065e-04

# %%
y_hat = lstm_model.predict(X_train)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.plot(range(len(y_train)), y_train)
plt.plot(range(len(y_hat)), y_hat)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step

# %%
m1=np.reshape(lstm_model.predict(X_test),(10,))
rmsle(y_test,m1)
m1*data.Close.max()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# array([230.40807, 231.28021, 232.11581, 232.52403, 232.68849, 232.74738,
#        232.86316, 232.99933, 232.88208, 232.3585 ], dtype=float32)

# %% [markdown]
# RNN find out structure of trend when LSTM find the general pattern of moevment in price so they get mixed to give us the best results

# %%
final=(m1*0.6+m*0.4)

# %%
final*data.Close.max()
# Out:
# array([229.95886, 230.53575, 231.138  , 231.52919, 231.80156, 230.3248 ,
#        230.2088 , 230.20036, 230.13493, 211.07332], dtype=float32)

# %%
from sklearn.metrics import mean_squared_log_error, mean_absolute_error

def rmsle(y_test, y_preds):
    return np.sqrt(mean_squared_log_error(y_test, y_preds))

# Create function to evaluate our model

# %% [markdown]
# tree model get trained and from the base on the results it works like LSTM here

# %%
from sklearn.ensemble import RandomForestRegressor
ideal_model = RandomForestRegressor(n_estimators=400,
                                    max_features=0.75,
                                    n_jobs=-1,
                                    max_samples=None)
ideal_model.fit(X_train, y_train)

val_preds = ideal_model.predict(X_test)
rmsle(y_test,val_preds)
# Out:
# 0.006769418819812963

# %%
ideal_model.predict(X_test)*data.Close.max()
# Out:
# array([231.64787479, 231.27567471, 230.83442535, 230.46250034,
#        229.57682529, 230.07287514, 229.90937492, 229.63712475,
#        229.43579948, 226.72799976])

# %%
m
# Out:
# array([0.9695748 , 0.97014153, 0.9712079 , 0.9727543 , 0.97459054,
#        0.95860505, 0.9566443 , 0.95569146, 0.9557435 , 0.7575505 ],
#       dtype=float32)

# %%
hybrid_result=final*0.4+ideal_model.predict(X_test)*0.6
rmsle(y_test,hybrid_result)
# Out:
# 0.0060112864999324785

# %%
hybrid_result*data.Close.max()
# Out:
# array([232.31019482, 232.26945127, 232.22222747, 232.22069296,
#        231.89547407, 231.86591669, 231.8178408 , 231.71615061,
#        231.65540146, 224.41494727])

# %% [markdown]
# the last model is linear model and it prefects for using with neural models for this kind of Databases

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()
lin_model.fit(X_train, y_train)
lin=lin_model.predict(X_test)

# %%
lin*data.Close.max()
# Out:
# array([239.36503128, 232.72723197, 236.06682541, 230.47521447,
#        232.29335578, 232.45090579, 232.25164943, 233.86869614,
#        227.51164322, 225.80306834])

# %%
hybrid_result=final*0.3+lin*0.7
rmsle(y_test,hybrid_result)
# Out:
# 0.00484282569697361

# %% [markdown]
# the reuslt is very close to the test data and the important thing is it nearly followed the test trend

# %%
hybrid_result*data.Close.max()
# Out:
# array([236.54317952, 232.06978921, 234.58817826, 230.79140811,
#        232.14582457, 231.81308001, 231.63879924, 232.76820183,
#        228.29863708, 221.38414782])

# %%
data.Close[-10:]
# Out:
# 242    236.479996
# 243    235.860001
# 244    230.759995
# 245    230.570007
# 246    231.410004
# 247    233.399994
# 248    233.669998
# 249    230.100006
# 250    225.910004
# 251    222.910004
# Name: Close, dtype: float64
